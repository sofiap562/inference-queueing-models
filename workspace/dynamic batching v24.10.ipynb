# %% [markdown]
# NVIDIA Release 24.10 (build 117849258)
# Triton Server Version 2.51.0

# %% [raw]
# name: "food_classifier_onnx"
# backend: "onnxruntime"
# max_batch_size: 16
# input [
#   {
#     name: "input"  # has to match ONNX model's input name
#     data_type: TYPE_FP32
#     dims: [3, 224, 224]  # has to match ONNX input shape
#   }
# ]
# output [
#   {
#     name: "output"  # has to match ONNX model output name
#     data_type: TYPE_FP32  # output is a list of probabilities
#     dims: [11]  #
#   }
# ]
#   instance_group [
#     {
#       count: 1
#       kind: KIND_GPU
#       gpus: [ 0 ]
#     }
# ]
# dynamic_batching {
#
# preferred_batch_size: [1, 2, 4, 6, 8]
#
# max_queue_delay_microseconds: 100
#
# }

# %%
#warmup
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 100 --request-count=1620 --warmup-request-count=100 --async -f test_warmup.csv

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 100 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 100 inference requests per second
# WARNING: Pass contained only one request, so sample latency standard deviation will be infinity (UINT64_MAX).
# No valid requests recorded within time interval. Please use a larger time window.

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 50 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 50 inference requests per second
# No valid requests recorded within time interval. Please use a larger time window.

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 336
#     Throughput: 18.1626 infer/sec
#     Avg latency: 31795 usec (standard deviation 7214 usec)
#     p50 latency: 28062 usec
#     p90 latency: 43103 usec
#     p95 latency: 47659 usec
#     p99 latency: 54958 usec
#     Avg HTTP time: 31661 usec (send/recv 1312 usec + response wait 30349 usec)
#   Server:
#     Inference count: 337
#     Execution count: 319
#     Successful request count: 337
#     Avg request latency: 20756 usec (overhead 163 usec + queue 3267 usec + compute input 560 usec + compute infer 16686 usec + compute output 79 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 18.1626 infer/sec, latency 31795 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 20 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 392
#     Throughput: 19.9489 infer/sec
#     Avg latency: 29883 usec (standard deviation 4542 usec)
#     p50 latency: 29581 usec
#     p90 latency: 30000 usec
#     p95 latency: 30393 usec
#     p99 latency: 37911 usec
#     Avg HTTP time: 29615 usec (send/recv 4571 usec + response wait 25044 usec)
#   Server:
#     Inference count: 392
#     Execution count: 392
#     Successful request count: 392
#     Avg request latency: 17466 usec (overhead 161 usec + queue 515 usec + compute input 509 usec + compute infer 16203 usec + compute output 78 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 19.9489 infer/sec, latency 29883 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 344
#     Throughput: 18.3409 infer/sec
#     Avg latency: 34027 usec (standard deviation 6997 usec)
#     p50 latency: 30534 usec
#     p90 latency: 44655 usec
#     p95 latency: 48955 usec
#     p99 latency: 56246 usec
#     Avg HTTP time: 33903 usec (send/recv 4380 usec + response wait 29523 usec)
#   Server:
#     Inference count: 344
#     Execution count: 326
#     Successful request count: 344
#     Avg request latency: 20569 usec (overhead 167 usec + queue 3088 usec + compute input 536 usec + compute infer 16698 usec + compute output 80 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 18.3409 infer/sec, latency 34027 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 30 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 30 inference requests per second
# Failed to obtain stable measurement.
# Failed to obtain stable measurement.

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 40 --async -f result_test40.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 40 inference requests per second
#   Client:
#     Request count: 806
#     Throughput: 40.5353 infer/sec
#     Avg latency: 35971 usec (standard deviation 10125 usec)
#     p50 latency: 33469 usec
#     p90 latency: 48373 usec
#     p95 latency: 52078 usec
#     p99 latency: 63042 usec
#     Avg HTTP time: 35659 usec (send/recv 1347 usec + response wait 34312 usec)
#   Server:
#     Inference count: 806
#     Execution count: 665
#     Successful request count: 806
#     Avg request latency: 23986 usec (overhead 186 usec + queue 5807 usec + compute input 721 usec + compute infer 17191 usec + compute output 80 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 40, throughput: 40.5353 infer/sec, latency 35971 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 50 --async -f result_test50.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 50 inference requests per second
#   Client:
#     Request count: 1045
#     Throughput: 49.4471 infer/sec
#     Avg latency: 40956 usec (standard deviation 13163 usec)
#     p50 latency: 38833 usec
#     p90 latency: 54361 usec
#     p95 latency: 59141 usec
#     p99 latency: 80848 usec
#     Avg HTTP time: 40464 usec (send/recv 2991 usec + response wait 37473 usec)
#   Server:
#     Inference count: 1041
#     Execution count: 799
#     Successful request count: 1041
#     Avg request latency: 25212 usec (overhead 198 usec + queue 6619 usec + compute input 854 usec + compute infer 17457 usec + compute output 83 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 50, throughput: 49.4471 infer/sec, latency 40956 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 60 --async -f result_test60.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 60 inference requests per second
#   Client:
#     Request count: 1143
#     Throughput: 58.1236 infer/sec
#     Avg latency: 42459 usec (standard deviation 13960 usec)
#     p50 latency: 39703 usec
#     p90 latency: 60102 usec
#     p95 latency: 68018 usec
#     p99 latency: 79871 usec
#     Avg HTTP time: 42063 usec (send/recv 1864 usec + response wait 40199 usec)
#   Server:
#     Inference count: 1142
#     Execution count: 778
#     Successful request count: 1142
#     Avg request latency: 26698 usec (overhead 221 usec + queue 7257 usec + compute input 1172 usec + compute infer 17960 usec + compute output 86 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 60, throughput: 58.1236 infer/sec, latency 42459 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 60 --async -f result_test60.csv

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 20 --async -f const20.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 392
#     Throughput: 19.9563 infer/sec
#     Avg latency: 30473 usec (standard deviation 4314 usec)
#     p50 latency: 30111 usec
#     p90 latency: 30602 usec
#     p95 latency: 30902 usec
#     p99 latency: 44555 usec
#     Avg HTTP time: 30203 usec (send/recv 4585 usec + response wait 25618 usec)
#   Server:
#     Inference count: 392
#     Execution count: 392
#     Successful request count: 392
#     Avg request latency: 17504 usec (overhead 155 usec + queue 544 usec + compute input 462 usec + compute infer 16268 usec + compute output 74 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 19.9563 infer/sec, latency 30473 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 30 --async -f const30.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 30 inference requests per second
#   Client:
#     Request count: 610
#     Throughput: 29.9462 infer/sec
#     Avg latency: 31425 usec (standard deviation 10983 usec)
#     p50 latency: 30160 usec
#     p90 latency: 30851 usec
#     p95 latency: 32683 usec
#     p99 latency: 56197 usec
#     Avg HTTP time: 30750 usec (send/recv 4775 usec + response wait 25975 usec)
#   Server:
#     Inference count: 610
#     Execution count: 606
#     Successful request count: 610
#     Avg request latency: 17750 usec (overhead 158 usec + queue 762 usec + compute input 497 usec + compute infer 16258 usec + compute output 75 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 30, throughput: 29.9462 infer/sec, latency 31425 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 40 --async -f const40.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 40 inference requests per second
#   Client:
#     Request count: 897
#     Avg send request rate: 37.62 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.00% of the requests were delayed.
#     Throughput: 39.97 infer/sec
#     Avg latency: 32581 usec (standard deviation 14881 usec)
#     p50 latency: 30387 usec
#     p90 latency: 31929 usec
#     p95 latency: 38630 usec
#     p99 latency: 85242 usec
#     Avg HTTP time: 31743 usec (send/recv 4856 usec + response wait 26887 usec)
#   Server:
#     Inference count: 898
#     Execution count: 882
#     Successful request count: 898
#     Avg request latency: 18166 usec (overhead 159 usec + queue 810 usec + compute input 490 usec + compute infer 16630 usec + compute output 76 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 40.00, throughput: 39.97 infer/sec, latency 32581 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 50 --async -f const50.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 50 inference requests per second
#   Client:
#     Request count: 987
#     Throughput: 50.013 infer/sec
#     Avg latency: 27547 usec (standard deviation 2561 usec)
#     p50 latency: 27073 usec
#     p90 latency: 28259 usec
#     p95 latency: 29361 usec
#     p99 latency: 41216 usec
#     Avg HTTP time: 27403 usec (send/recv 1482 usec + response wait 25921 usec)
#   Server:
#     Inference count: 987
#     Execution count: 985
#     Successful request count: 987
#     Avg request latency: 17466 usec (overhead 136 usec + queue 549 usec + compute input 453 usec + compute infer 16252 usec + compute output 75 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 50, throughput: 50.013 infer/sec, latency 27547 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 60 --async -f const60.csv

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --async -f poisson20.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 350
#     Throughput: 18.0745 infer/sec
#     Avg latency: 34763 usec (standard deviation 8151 usec)
#     p50 latency: 31203 usec
#     p90 latency: 46550 usec
#     p95 latency: 50653 usec
#     p99 latency: 64384 usec
#     Avg HTTP time: 34311 usec (send/recv 4489 usec + response wait 29822 usec)
#   Server:
#     Inference count: 350
#     Execution count: 332
#     Successful request count: 350
#     Avg request latency: 20633 usec (overhead 169 usec + queue 3082 usec + compute input 592 usec + compute infer 16712 usec + compute output 77 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 18.0745 infer/sec, latency 34763 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --measurement-interval=10000  --async -f poisson20long.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 10000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 728
#     Throughput: 19.0447 infer/sec
#     Avg latency: 35058 usec (standard deviation 10292 usec)
#     p50 latency: 31020 usec
#     p90 latency: 46530 usec
#     p95 latency: 50767 usec
#     p99 latency: 61199 usec
#     Avg HTTP time: 34571 usec (send/recv 4619 usec + response wait 29952 usec)
#   Server:
#     Inference count: 728
#     Execution count: 683
#     Successful request count: 728
#     Avg request latency: 21032 usec (overhead 167 usec + queue 3494 usec + compute input 570 usec + compute infer 16723 usec + compute output 78 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 19.0447 infer/sec, latency 35058 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 40 --measurement-interval=10000 --async -f poisson40long.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 10000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 40 inference requests per second
#   Client:
#     Request count: 1668
#     Avg send request rate: 41.31 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.02% of the requests were delayed.
#     Throughput: 38.81 infer/sec
#     Avg latency: 38605 usec (standard deviation 21248 usec)
#     p50 latency: 35082 usec
#     p90 latency: 51106 usec
#     p95 latency: 55724 usec
#     p99 latency: 66086 usec
#     Avg HTTP time: 37828 usec (send/recv 3622 usec + response wait 34206 usec)
#   Server:
#     Inference count: 1668
#     Execution count: 1369
#     Successful request count: 1668
#     Avg request latency: 24052 usec (overhead 187 usec + queue 5688 usec + compute input 765 usec + compute infer 17330 usec + compute output 80 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 40.00, throughput: 38.81 infer/sec, latency 38605 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 50 --measurement-interval=30000  --async -f poisson50.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 30000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 50 inference requests per second
#   Client:
#     Request count: 6165
#     Avg send request rate: 51.11 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.64% of the requests were delayed.
#     Throughput: 49.11 infer/sec
#     Avg latency: 43744 usec (standard deviation 33561 usec)
#     p50 latency: 39411 usec
#     p90 latency: 56850 usec
#     p95 latency: 64329 usec
#     p99 latency: 136612 usec
#     Avg HTTP time: 42978 usec (send/recv 3580 usec + response wait 39398 usec)
#   Server:
#     Inference count: 6165
#     Execution count: 4593
#     Successful request count: 6165
#     Avg request latency: 25626 usec (overhead 204 usec + queue 6627 usec + compute input 927 usec + compute infer 17783 usec + compute output 84 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 50.00, throughput: 49.11 infer/sec, latency 43744 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 100 --measurement-interval=10000 --async -f poisson60.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 10000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 100 inference requests per second
#   Client:
#     Request count: 4904
#     Avg send request rate: 97.23 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.92% of the requests were delayed.
#     Throughput: 101.46 infer/sec
#     Avg latency: 49955 usec (standard deviation 26565 usec)
#     p50 latency: 45486 usec
#     p90 latency: 66749 usec
#     p95 latency: 81192 usec
#     p99 latency: 137635 usec
#     Avg HTTP time: 49218 usec (send/recv 1848 usec + response wait 47370 usec)
#   Server:
#     Inference count: 4907
#     Execution count: 2238
#     Successful request count: 4907
#     Avg request latency: 30433 usec (overhead 304 usec + queue 9320 usec + compute input 1984 usec + compute infer 18727 usec + compute output 98 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 100.00, throughput: 101.46 infer/sec, latency 49955 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 110 --measurement-interval=10000 --async -f poisson10.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 10000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 110 inference requests per second
#   Client:
#     Request count: 14771
#     Avg send request rate: 115.66 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 10.01% of the requests were delayed.
#     Throughput: 110.97 infer/sec
#     Avg latency: 119914 usec (standard deviation 29831 usec)
#     p50 latency: 55879 usec
#     p90 latency: 340889 usec
#     p95 latency: 516747 usec
#     p99 latency: 845312 usec
#     Avg HTTP time: 116544 usec (send/recv 12916 usec + response wait 103628 usec)
#   Server:
#     Inference count: 14771
#     Execution count: 5979
#     Successful request count: 14771
#     Avg request latency: 33037 usec (overhead 343 usec + queue 10756 usec + compute input 2864 usec + compute infer 18964 usec + compute output 108 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 110.00, throughput: 110.97 infer/sec, latency 119914 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 120 --measurement-interval=10000 --async -f poisson120.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 10000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 120 inference requests per second
#   Client:
#     Request count: 6271
#     Avg send request rate: 111.40 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 4.39% of the requests were delayed.
#     Throughput: 118.80 infer/sec
#     Avg latency: 70033 usec (standard deviation 34641 usec)
#     p50 latency: 54882 usec
#     p90 latency: 103492 usec
#     p95 latency: 159682 usec
#     p99 latency: 308673 usec
#     Avg HTTP time: 68793 usec (send/recv 3052 usec + response wait 65741 usec)
#   Server:
#     Inference count: 6268
#     Execution count: 2393
#     Successful request count: 6268
#     Avg request latency: 32421 usec (overhead 347 usec + queue 10142 usec + compute input 2686 usec + compute infer 19136 usec + compute output 109 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 120.00, throughput: 118.80 infer/sec, latency 70033 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 200 --measurement-interval=10000 --async -f poisson200.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 10000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 200 inference requests per second
