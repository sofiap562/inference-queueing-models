# %% [markdown]
# NVIDIA Release 25.08 (build 202022639)
# Triton Server Version 2.60.0

# %% [raw]
# name: "food_classifier_onnx"
# backend: "onnxruntime"
# max_batch_size: 16
# input [
#   {
#     name: "input"  # has to match ONNX model's input name
#     data_type: TYPE_FP32
#     dims: [3, 224, 224]  # has to match ONNX input shape
#   }
# ]
# output [
#   {
#     name: "output"  # has to match ONNX model output name
#     data_type: TYPE_FP32  # output is a list of probabilities
#     dims: [11]  #
#   }
# ]
#   instance_group [
#     {
#       count: 1
#       kind: KIND_GPU
#       gpus: [ 0 ]
#     }
# ]

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1762786757098,"inference_count":1720,"execution_count":1720,"inference_stats":{"success":{"count":1720,"ns":1863030374745},"fail":{"count":0,"ns":0},"queue":{"count":1720,"ns":1829457511724},"compute_input":{"count":1720,"ns":976040299},"compute_infer":{"count":1720,"ns":32224052674},"compute_output":{"count":1720,"ns":129250817},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":1720,"ns":976040299},"compute_infer":{"count":1720,"ns":32224052674},"compute_output":{"count":1720,"ns":129250817}}],"memory_usage":[]}]}

# %%
#warmup
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 100 --request-count=1620 --warmup-request-count=100 --async -f test_warmup.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 100 warmup requests
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 100 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 89.7824 infer/sec
#     Avg latency: 354381 usec (standard deviation 100611 usec)
#     p50 latency: 387844 usec
#     p90 latency: 518884 usec
#     p95 latency: 537145 usec
#     p99 latency: 562641 usec
#     Avg HTTP time: 354242 usec (send/recv 3707 usec + response wait 350535 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 1620
#     Successful request count: 1620
#     Avg request latency: 330491 usec (overhead 141 usec + queue 320123 usec + compute input 582 usec + compute infer 9568 usec + compute output 76 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 100, throughput: 89.7824 infer/sec, latency 354381 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 100 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 100 inference requests per second
#   Client:
#     Request count: 2202
#     Avg send request rate: 96.65 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 2.63% of the requests were delayed.
#     Throughput: 97.27 infer/sec
#     Avg latency: 1359729 usec (standard deviation 36543 usec)
#     p50 latency: 1355025 usec
#     p90 latency: 1502851 usec
#     p95 latency: 1538484 usec
#     p99 latency: 1573182 usec
#     Avg HTTP time: 1358705 usec (send/recv 3521 usec + response wait 1355184 usec)
#   Server:
#     Inference count: 2202
#     Execution count: 2202
#     Successful request count: 2202
#     Avg request latency: 1330277 usec (overhead 140 usec + queue 1320077 usec + compute input 433 usec + compute infer 9552 usec + compute output 74 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 100.00, throughput: 97.27 infer/sec, latency 1359729 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 50 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 50 inference requests per second
#   Client:
#     Request count: 945
#     Throughput: 49.3312 infer/sec
#     Avg latency: 29559 usec (standard deviation 11344 usec)
#     p50 latency: 25634 usec
#     p90 latency: 44601 usec
#     p95 latency: 51842 usec
#     p99 latency: 72555 usec
#     Avg HTTP time: 29210 usec (send/recv 2223 usec + response wait 26987 usec)
#   Server:
#     Inference count: 945
#     Execution count: 945
#     Successful request count: 945
#     Avg request latency: 16388 usec (overhead 146 usec + queue 6193 usec + compute input 437 usec + compute infer 9536 usec + compute output 74 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 50, throughput: 49.3312 infer/sec, latency 29559 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 345
#     Throughput: 18.2599 infer/sec
#     Avg latency: 25426 usec (standard deviation 5503 usec)
#     p50 latency: 23290 usec
#     p90 latency: 33514 usec
#     p95 latency: 37523 usec
#     p99 latency: 48193 usec
#     Avg HTTP time: 25295 usec (send/recv 4415 usec + response wait 20880 usec)
#   Server:
#     Inference count: 345
#     Execution count: 345
#     Successful request count: 345
#     Avg request latency: 12058 usec (overhead 162 usec + queue 1761 usec + compute input 414 usec + compute infer 9642 usec + compute output 77 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 18.2599 infer/sec, latency 25426 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=constant --request-rate-range 20 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
#   Client:
#     Request count: 392
#     Throughput: 19.9641 infer/sec
#     Avg latency: 23066 usec (standard deviation 4137 usec)
#     p50 latency: 22758 usec
#     p90 latency: 23486 usec
#     p95 latency: 23724 usec
#     p99 latency: 31068 usec
#     Avg HTTP time: 22774 usec (send/recv 4604 usec + response wait 18170 usec)
#   Server:
#     Inference count: 392
#     Execution count: 392
#     Successful request count: 392
#     Avg request latency: 10321 usec (overhead 155 usec + queue 201 usec + compute input 427 usec + compute infer 9463 usec + compute output 74 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 20, throughput: 19.9641 infer/sec, latency 23066 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
# Failed to obtain stable measurement.
# Failed to obtain stable measurement.

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 30 --async -f result_test.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 30 inference requests per second
#   Client:
#     Request count: 566
#     Throughput: 28.8992 infer/sec
#     Avg latency: 27775 usec (standard deviation 8188 usec)
#     p50 latency: 24040 usec
#     p90 latency: 37762 usec
#     p95 latency: 42056 usec
#     p99 latency: 57365 usec
#     Avg HTTP time: 27713 usec (send/recv 4775 usec + response wait 22938 usec)
#   Server:
#     Inference count: 567
#     Execution count: 567
#     Successful request count: 567
#     Avg request latency: 13011 usec (overhead 154 usec + queue 2845 usec + compute input 450 usec + compute infer 9484 usec + compute output 76 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 30, throughput: 28.8992 infer/sec, latency 27775 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 40 --async -f result_test40.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 40 inference requests per second
#   Client:
#     Request count: 786
#     Throughput: 40.2585 infer/sec
#     Avg latency: 28016 usec (standard deviation 10034 usec)
#     p50 latency: 23939 usec
#     p90 latency: 38618 usec
#     p95 latency: 44743 usec
#     p99 latency: 63791 usec
#     Avg HTTP time: 27643 usec (send/recv 3774 usec + response wait 23869 usec)
#   Server:
#     Inference count: 786
#     Execution count: 786
#     Successful request count: 786
#     Avg request latency: 14007 usec (overhead 150 usec + queue 3816 usec + compute input 438 usec + compute infer 9527 usec + compute output 75 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 40, throughput: 40.2585 infer/sec, latency 28016 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 50 --async -f result_test50.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 50 inference requests per second
#   Client:
#     Request count: 958
#     Throughput: 48.4422 infer/sec
#     Avg latency: 29594 usec (standard deviation 9819 usec)
#     p50 latency: 26395 usec
#     p90 latency: 43878 usec
#     p95 latency: 48473 usec
#     p99 latency: 59173 usec
#     Avg HTTP time: 29406 usec (send/recv 3420 usec + response wait 25986 usec)
#   Server:
#     Inference count: 958
#     Execution count: 958
#     Successful request count: 958
#     Avg request latency: 15610 usec (overhead 144 usec + queue 5489 usec + compute input 413 usec + compute infer 9490 usec + compute output 74 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 50, throughput: 48.4422 infer/sec, latency 29594 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 60 --async -f result_test60.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 60 inference requests per second
#   Client:
#     Request count: 1274
#     Throughput: 58.2376 infer/sec
#     Avg latency: 32101 usec (standard deviation 15049 usec)
#     p50 latency: 28309 usec
#     p90 latency: 48468 usec
#     p95 latency: 57289 usec
#     p99 latency: 79977 usec
#     Avg HTTP time: 31646 usec (send/recv 2545 usec + response wait 29101 usec)
#   Server:
#     Inference count: 1274
#     Execution count: 1274
#     Successful request count: 1274
#     Avg request latency: 18253 usec (overhead 142 usec + queue 8191 usec + compute input 378 usec + compute infer 9468 usec + compute output 73 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 60, throughput: 58.2376 infer/sec, latency 32101 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 8 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 60 --async -f result_test60.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 8
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 60 inference requests per second
# Warning: Request latency is not stabilizing. Please try lowering the request rate.
#   Client:
#     Request count: 1352
#     Avg send request rate: 62.18 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.85% of the requests were delayed.
#     Throughput: 470.63 infer/sec
#     Avg latency: 13123927 usec (standard deviation 68709 usec)
#     p50 latency: 6353365 usec
#     p90 latency: 42480236 usec
#     p95 latency: 45055723 usec
#     p99 latency: 45947013 usec
#     Avg HTTP time: 13154551 usec (send/recv 8776001 usec + response wait 4378550 usec)
#   Server:
#     Inference count: 10816
#     Execution count: 1352
#     Successful request count: 1352
#     Avg request latency: 37309 usec (overhead 137 usec + queue 24519 usec + compute input 3471 usec + compute infer 9104 usec + compute output 77 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 60.00, throughput: 470.63 infer/sec, latency 13123927 usec

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 8 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 20 --async -f result_test60.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 8
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
# Failed to obtain stable measurement.
# Failed to obtain stable measurement.

# %%
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 8 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 30 --async -f result_test60.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 8
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 30 inference requests per second
# Failed to obtain stable measurement.
# Failed to obtain stable measurement.
