# %% [markdown]
# ## Queueing Delay vs Load Relationship

# %% [markdown]
# Find out the queuing delay vs load relationship. for a reasonable setup (dynamic batching with e.g. max 8/min 1 batch size), run experiments with increasing load levels and Poisson arrivals. Save the traces, and also use them compute the average queuing delay (discarding the first X seconds to eliminate those excessive service times). Plot queuing delay vs load.

# %% [markdown]
# First we need to edit the model's configuration:
#
# nano ~/summer2025/models/food_classifier_onnx/config.pbtxt
#
# and at the end, add
#
# dynamic_batching {
#
#   preferred_batch_size: [1, 2, 4, 6, 8]
#
#   max_queue_delay_microseconds: 100
#
# }
#
#
# Save the file (use Ctrl+O then Enter, then Ctrl+X).
#
# Re-build the container image with this change:
#
# docker compose -f ~/summer2025/docker/docker-compose.yaml build triton_server
# and then bring the server back up:
#
# docker compose -f ~/summer2025/docker/docker-compose.yaml up triton_server --force-recreate -d

# %% [markdown]
# To enable tracing we need to follow the steps below:
#
# # Steps to activate tracing
#
# "wget https://github.com/triton-inference-server/server/blob/8d0b87a575f04278b571cfae1a01be5fcf6175d4/qa/common/trace_summary.py"
#
# "nano summer2025/docker/docker-compose.yaml"
#
# "command: tritonserver --trace-file=/tmp/trace.json --trace-rate=1 --trace-count=20000 --trace-log-frequency=4000 --trace-level=TIMESTAMPS --model-repository=/models"
#  * trace-rate = 1 -> so that we trace every request
#  * trace-count => the server will stop tracing after that many requests
#  * trace-log-frequency => should match how many requests we send in the benchmark (request-rate*request-count) -> each trace file will contain this many request traces
#
# Then build and force recreate the server:
#
# "docker compose -f ~/summer2025/docker/docker-compose.yaml build triton_server"
#
# "docker compose -f ~/summer2025/docker/docker-compose.yaml up triton_server --force-recreate -d"
#
# To see the trace files logged:
#
# "docker exec triton_server ls -alstr /tmp/"
#
# To copy them to the jupyter interface:
#
# "docker cp triton_server:/tmp/trace.json.1 ."
#
# "docker cp trace.json.1 jupyter:/home/jovyan/work/trace_qd_1.json"

# %% [markdown]
# Expected waiting time is
# $$\frac{1}{2\mu}\cdot\frac{\rho}{1-\rho}$$

# %% [markdown]
# From previous notebook we determined that the request rate range that corresponds to rho values ranging from 0.1 to 0.9 (w a 0.1 step) is 162:729:81

# %% [markdown]
# Run the following benchmark multiple times, increasing the arrival rate. Once the throughput is much less than the arrival rate make a not of the throughput.

# %% [markdown]
# Expected waiting time is
# $$\frac{1}{2\mu}\cdot\frac{\rho}{1-\rho}$$

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":0,"inference_count":0,"execution_count":0,"inference_stats":{"success":{"count":0,"ns":0},"fail":{"count":0,"ns":0},"queue":{"count":0,"ns":0},"compute_input":{"count":0,"ns":0},"compute_infer":{"count":0,"ns":0},"compute_output":{"count":0,"ns":0},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[],"memory_usage":[]}]}

# %%
#warmup
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 162 --request-count=1620 --async -f test_warmup.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 162 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 134.983 infer/sec
#     Avg latency: 1740592 usec (standard deviation 87686 usec)
#     p50 latency: 1710686 usec
#     p90 latency: 3053882 usec
#     p95 latency: 3546872 usec
#     p99 latency: 3985955 usec
#     Avg HTTP time: 1740583 usec (send/recv 546 usec + response wait 1740037 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 208
#     Successful request count: 1620
#     Avg request latency: 1738614 usec (overhead 139 usec + queue 1706418 usec + compute input 627 usec + compute infer 31406 usec + compute output 23 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 162, throughput: 134.983 infer/sec, latency 1740592 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918008476,"inference_count":1620,"execution_count":208,"inference_stats":{"success":{"count":1620,"ns":2816555721061},"fail":{"count":0,"ns":0},"queue":{"count":1620,"ns":2764397993479},"compute_input":{"count":1620,"ns":1015866695},"compute_infer":{"count":1620,"ns":50878690625},"compute_output":{"count":1620,"ns":37845190},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":4,"ns":607563},"compute_infer":{"count":4,"ns":3877619319},"compute_output":{"count":4,"ns":118440}},{"batch_size":2,"compute_input":{"count":2,"ns":427130},"compute_infer":{"count":2,"ns":1174605047},"compute_output":{"count":2,"ns":50009}},{"batch_size":4,"compute_input":{"count":1,"ns":361842},"compute_infer":{"count":1,"ns":449603905},"compute_output":{"count":1,"ns":33123}},{"batch_size":8,"compute_input":{"count":201,"ns":126619688},"compute_infer":{"count":201,"ns":5356680699},"compute_output":{"count":201,"ns":4686780}}],"memory_usage":[]}]}

# %%
#warmup
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 162 --request-count=1620 --async -f test_rr162.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 162 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 134.983 infer/sec
#     Avg latency: 1632148 usec (standard deviation 53783 usec)
#     p50 latency: 1626935 usec
#     p90 latency: 2864909 usec
#     p95 latency: 3045425 usec
#     p99 latency: 3334783 usec
#     Avg HTTP time: 1632140 usec (send/recv 497 usec + response wait 1631643 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 207
#     Successful request count: 1620
#     Avg request latency: 1630467 usec (overhead 137 usec + queue 1592530 usec + compute input 626 usec + compute infer 37149 usec + compute output 24 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 162, throughput: 134.983 infer/sec, latency 1632148 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918022226,"inference_count":3240,"execution_count":415,"inference_stats":{"success":{"count":3240,"ns":5457913572397},"fail":{"count":0,"ns":0},"queue":{"count":3240,"ns":5344296911402},"compute_input":{"count":3240,"ns":2030340074},"compute_infer":{"count":3240,"ns":111061136819},"compute_output":{"count":3240,"ns":77313867},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":8,"ns":1170952},"compute_infer":{"count":8,"ns":6692159171},"compute_output":{"count":8,"ns":239336}},{"batch_size":2,"compute_input":{"count":2,"ns":427130},"compute_infer":{"count":2,"ns":1174605047},"compute_output":{"count":2,"ns":50009}},{"batch_size":3,"compute_input":{"count":1,"ns":289611},"compute_infer":{"count":1,"ns":1133575499},"compute_output":{"count":1,"ns":49961}},{"batch_size":4,"compute_input":{"count":1,"ns":361842},"compute_infer":{"count":1,"ns":449603905},"compute_output":{"count":1,"ns":33123}},{"batch_size":6,"compute_input":{"count":1,"ns":586427},"compute_infer":{"count":1,"ns":859799297},"compute_output":{"count":1,"ns":40407}},{"batch_size":7,"compute_input":{"count":1,"ns":718005},"compute_infer":{"count":1,"ns":884899385},"compute_output":{"count":1,"ns":57112}},{"batch_size":8,"compute_input":{"count":401,"ns":252181758},"compute_infer":{"count":401,"ns":10683441745},"compute_output":{"count":401,"ns":9506239}}],"memory_usage":[]}]}

# %%
#trace 2
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 243 --request-count=1620 --async -f test_rr243.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 243 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 161.978 infer/sec
#     Avg latency: 1527351 usec (standard deviation 78914 usec)
#     p50 latency: 1552541 usec
#     p90 latency: 2659989 usec
#     p95 latency: 2777037 usec
#     p99 latency: 2968205 usec
#     Avg HTTP time: 1527342 usec (send/recv 520 usec + response wait 1526822 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 207
#     Successful request count: 1620
#     Avg request latency: 1525433 usec (overhead 127 usec + queue 1494263 usec + compute input 715 usec + compute infer 30303 usec + compute output 24 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 243, throughput: 161.978 infer/sec, latency 1527351 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918033836,"inference_count":4860,"execution_count":622,"inference_stats":{"success":{"count":4860,"ns":7929116417501},"fail":{"count":0,"ns":0},"queue":{"count":4860,"ns":7765004444029},"compute_input":{"count":4860,"ns":3189970625},"compute_infer":{"count":4860,"ns":160152496486},"compute_output":{"count":4860,"ns":117240875},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":12,"ns":1732907},"compute_infer":{"count":12,"ns":9505551506},"compute_output":{"count":12,"ns":355932}},{"batch_size":2,"compute_input":{"count":2,"ns":427130},"compute_infer":{"count":2,"ns":1174605047},"compute_output":{"count":2,"ns":50009}},{"batch_size":3,"compute_input":{"count":1,"ns":289611},"compute_infer":{"count":1,"ns":1133575499},"compute_output":{"count":1,"ns":49961}},{"batch_size":4,"compute_input":{"count":3,"ns":1107561},"compute_infer":{"count":3,"ns":1356340172},"compute_output":{"count":3,"ns":101608}},{"batch_size":6,"compute_input":{"count":1,"ns":586427},"compute_infer":{"count":1,"ns":859799297},"compute_output":{"count":1,"ns":40407}},{"batch_size":7,"compute_input":{"count":1,"ns":718005},"compute_infer":{"count":1,"ns":884899385},"compute_output":{"count":1,"ns":57112}},{"batch_size":8,"compute_input":{"count":602,"ns":396692473},"compute_infer":{"count":602,"ns":16014819528},"compute_output":{"count":602,"ns":14448298}}],"memory_usage":[]}]}

# %%
#trace 2
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 324 --request-count=1620 --async -f test_rr324.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 324 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 202.469 infer/sec
#     Avg latency: 1785374 usec (standard deviation 47198 usec)
#     p50 latency: 1908454 usec
#     p90 latency: 2768729 usec
#     p95 latency: 2906253 usec
#     p99 latency: 3025935 usec
#     Avg HTTP time: 1785367 usec (send/recv 554 usec + response wait 1784813 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 206
#     Successful request count: 1620
#     Avg request latency: 1783255 usec (overhead 109 usec + queue 1758422 usec + compute input 820 usec + compute infer 23878 usec + compute output 24 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 324, throughput: 202.469 infer/sec, latency 1785374 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918043606,"inference_count":6480,"execution_count":828,"inference_stats":{"success":{"count":6480,"ns":10817990954861},"fail":{"count":0,"ns":0},"queue":{"count":6480,"ns":10613649652765},"compute_input":{"count":6480,"ns":4519980044},"compute_infer":{"count":6480,"ns":198835612024},"compute_output":{"count":6480,"ns":156996512},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":15,"ns":2922627},"compute_infer":{"count":15,"ns":11634137801},"compute_output":{"count":15,"ns":465514}},{"batch_size":2,"compute_input":{"count":3,"ns":571266},"compute_infer":{"count":3,"ns":1758874015},"compute_output":{"count":3,"ns":82188}},{"batch_size":3,"compute_input":{"count":1,"ns":289611},"compute_infer":{"count":1,"ns":1133575499},"compute_output":{"count":1,"ns":49961}},{"batch_size":4,"compute_input":{"count":3,"ns":1107561},"compute_infer":{"count":3,"ns":1356340172},"compute_output":{"count":3,"ns":101608}},{"batch_size":6,"compute_input":{"count":1,"ns":586427},"compute_infer":{"count":1,"ns":859799297},"compute_output":{"count":1,"ns":40407}},{"batch_size":7,"compute_input":{"count":2,"ns":1443562},"compute_infer":{"count":2,"ns":1764925174},"compute_output":{"count":2,"ns":91743}},{"batch_size":8,"compute_input":{"count":803,"ns":562124039},"compute_infer":{"count":803,"ns":19668045876},"compute_output":{"count":803,"ns":19365708}}],"memory_usage":[]}]}

# %%
#trace 3
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 405 --request-count=1620 --async -f test_rr405.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 405 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 202.468 infer/sec
#     Avg latency: 1840447 usec (standard deviation 103478 usec)
#     p50 latency: 1784128 usec
#     p90 latency: 3417495 usec
#     p95 latency: 3606141 usec
#     p99 latency: 3731408 usec
#     Avg HTTP time: 1840438 usec (send/recv 788 usec + response wait 1839650 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 206
#     Successful request count: 1620
#     Avg request latency: 1837531 usec (overhead 116 usec + queue 1811777 usec + compute input 858 usec + compute infer 24755 usec + compute output 24 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 405, throughput: 202.468 infer/sec, latency 1840447 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918053565,"inference_count":8100,"execution_count":1034,"inference_stats":{"success":{"count":8100,"ns":13794792737801},"fail":{"count":0,"ns":0},"queue":{"count":8100,"ns":13548728409065},"compute_input":{"count":8100,"ns":5910949869},"compute_infer":{"count":8100,"ns":238938995366},"compute_output":{"count":8100,"ns":196529755},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":18,"ns":3361192},"compute_infer":{"count":18,"ns":13764928095},"compute_output":{"count":18,"ns":562710}},{"batch_size":2,"compute_input":{"count":3,"ns":571266},"compute_infer":{"count":3,"ns":1758874015},"compute_output":{"count":3,"ns":82188}},{"batch_size":3,"compute_input":{"count":1,"ns":289611},"compute_infer":{"count":1,"ns":1133575499},"compute_output":{"count":1,"ns":49961}},{"batch_size":4,"compute_input":{"count":4,"ns":1545876},"compute_infer":{"count":4,"ns":1806548409},"compute_output":{"count":4,"ns":126428}},{"batch_size":5,"compute_input":{"count":1,"ns":402248},"compute_infer":{"count":1,"ns":1395214900},"compute_output":{"count":1,"ns":60835}},{"batch_size":6,"compute_input":{"count":1,"ns":586427},"compute_infer":{"count":1,"ns":859799297},"compute_output":{"count":1,"ns":40407}},{"batch_size":7,"compute_input":{"count":2,"ns":1443562},"compute_infer":{"count":2,"ns":1764925174},"compute_output":{"count":2,"ns":91743}},{"batch_size":8,"compute_input":{"count":1004,"ns":735469884},"compute_infer":{"count":1004,"ns":23317506576},"compute_output":{"count":1004,"ns":24244782}}],"memory_usage":[]}]}

# %%
#trace 4
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 486 --request-count=1620 --async -f test_rr486.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 486 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.939 infer/sec
#     Avg latency: 1613624 usec (standard deviation 92463 usec)
#     p50 latency: 1621678 usec
#     p90 latency: 2771974 usec
#     p95 latency: 2922100 usec
#     p99 latency: 3055220 usec
#     Avg HTTP time: 1613616 usec (send/recv 857 usec + response wait 1612759 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 1610581 usec (overhead 111 usec + queue 1598394 usec + compute input 833 usec + compute infer 11218 usec + compute output 24 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 486, throughput: 323.939 infer/sec, latency 1613624 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918059453,"inference_count":9720,"execution_count":1239,"inference_stats":{"success":{"count":9720,"ns":16403935533376},"fail":{"count":0,"ns":0},"queue":{"count":9720,"ns":16138127030630},"compute_input":{"count":9720,"ns":7261766365},"compute_infer":{"count":9720,"ns":257112357647},"compute_output":{"count":9720,"ns":235575352},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":20,"ns":4499110},"compute_infer":{"count":20,"ns":15179149438},"compute_output":{"count":20,"ns":625923}},{"batch_size":2,"compute_input":{"count":4,"ns":773123},"compute_infer":{"count":4,"ns":2339703656},"compute_output":{"count":4,"ns":107416}},{"batch_size":3,"compute_input":{"count":1,"ns":289611},"compute_infer":{"count":1,"ns":1133575499},"compute_output":{"count":1,"ns":49961}},{"batch_size":4,"compute_input":{"count":4,"ns":1545876},"compute_infer":{"count":4,"ns":1806548409},"compute_output":{"count":4,"ns":126428}},{"batch_size":5,"compute_input":{"count":1,"ns":402248},"compute_infer":{"count":1,"ns":1395214900},"compute_output":{"count":1,"ns":60835}},{"batch_size":6,"compute_input":{"count":1,"ns":586427},"compute_infer":{"count":1,"ns":859799297},"compute_output":{"count":1,"ns":40407}},{"batch_size":7,"compute_input":{"count":2,"ns":1443562},"compute_infer":{"count":2,"ns":1764925174},"compute_output":{"count":2,"ns":91743}},{"batch_size":8,"compute_input":{"count":1206,"ns":904129242},"compute_infer":{"count":1206,"ns":25267191783},"compute_output":{"count":1206,"ns":29111273}}],"memory_usage":[]}]}

# %%
#trace 4
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 567 --request-count=1620 --async -f test_rr567.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 567 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.945 infer/sec
#     Avg latency: 1882528 usec (standard deviation 89737 usec)
#     p50 latency: 1890873 usec
#     p90 latency: 2853095 usec
#     p95 latency: 2977635 usec
#     p99 latency: 3089659 usec
#     Avg HTTP time: 1882521 usec (send/recv 1183 usec + response wait 1881338 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 1878361 usec (overhead 118 usec + queue 1866094 usec + compute input 839 usec + compute infer 11285 usec + compute output 24 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 567, throughput: 323.945 infer/sec, latency 1882528 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1759918066069,"inference_count":11340,"execution_count":1444,"inference_stats":{"success":{"count":11340,"ns":19446881180668},"fail":{"count":0,"ns":0},"queue":{"count":11340,"ns":19161200682084},"compute_input":{"count":11340,"ns":8622040028},"compute_infer":{"count":11340,"ns":275395032245},"compute_output":{"count":11340,"ns":274805289},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":22,"ns":4817725},"compute_infer":{"count":22,"ns":16602144622},"compute_output":{"count":22,"ns":690304}},{"batch_size":2,"compute_input":{"count":5,"ns":998091},"compute_infer":{"count":5,"ns":2920584519},"compute_output":{"count":5,"ns":131586}},{"batch_size":3,"compute_input":{"count":1,"ns":289611},"compute_infer":{"count":1,"ns":1133575499},"compute_output":{"count":1,"ns":49961}},{"batch_size":4,"compute_input":{"count":4,"ns":1545876},"compute_infer":{"count":4,"ns":1806548409},"compute_output":{"count":4,"ns":126428}},{"batch_size":5,"compute_input":{"count":1,"ns":402248},"compute_infer":{"count":1,"ns":1395214900},"compute_output":{"count":1,"ns":60835}},{"batch_size":6,"compute_input":{"count":1,"ns":586427},"compute_infer":{"count":1,"ns":859799297},"compute_output":{"count":1,"ns":40407}},{"batch_size":7,"compute_input":{"count":2,"ns":1443562},"compute_infer":{"count":2,"ns":1764925174},"compute_output":{"count":2,"ns":91743}},{"batch_size":8,"compute_input":{"count":1408,"ns":1074067381},"compute_infer":{"count":1408,"ns":27229431494},"compute_output":{"count":1408,"ns":34000925}}],"memory_usage":[]}]}

# %% [markdown]
# Below I will run benchmarks with the same configuration just higher utilization (ρ = 0.5 - 1.1)

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":0,"inference_count":0,"execution_count":0,"inference_stats":{"success":{"count":0,"ns":0},"fail":{"count":0,"ns":0},"queue":{"count":0,"ns":0},"compute_input":{"count":0,"ns":0},"compute_infer":{"count":0,"ns":0},"compute_output":{"count":0,"ns":0},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[],"memory_usage":[]}]}

# %%
#trace 0
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 486 --request-count=1620 --async -f warmup2.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 486 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 269.953 infer/sec
#     Avg latency: 2726136 usec (standard deviation 98589 usec)
#     p50 latency: 2733473 usec
#     p90 latency: 3896124 usec
#     p95 latency: 4045292 usec
#     p99 latency: 4180196 usec
#     Avg HTTP time: 2726129 usec (send/recv 1184 usec + response wait 2724945 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 2721533 usec (overhead 143 usec + queue 2708667 usec + compute input 707 usec + compute infer 11993 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 486, throughput: 269.953 infer/sec, latency 2726136 usec

# %%
#after warmup
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963190720,"inference_count":1620,"execution_count":205,"inference_stats":{"success":{"count":1620,"ns":4408884583375},"fail":{"count":0,"ns":0},"queue":{"count":1620,"ns":4388041899893},"compute_input":{"count":1620,"ns":1145356802},"compute_infer":{"count":1620,"ns":19429696673},"compute_output":{"count":1620,"ns":37081591},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":2,"ns":369666},"compute_infer":{"count":2,"ns":2510830163},"compute_output":{"count":2,"ns":68391}},{"batch_size":2,"compute_input":{"count":1,"ns":199624},"compute_infer":{"count":1,"ns":577312827},"compute_output":{"count":1,"ns":17580}},{"batch_size":8,"compute_input":{"count":202,"ns":143073486},"compute_infer":{"count":202,"ns":1970530107},"compute_output":{"count":202,"ns":4622255}}],"memory_usage":[]}]}

# %%
#trace 1
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 486 --request-count=1620 --async -f test2_rr486.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 486 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.94 infer/sec
#     Avg latency: 1569739 usec (standard deviation 101359 usec)
#     p50 latency: 1576268 usec
#     p90 latency: 2738196 usec
#     p95 latency: 2889999 usec
#     p99 latency: 3023636 usec
#     Avg HTTP time: 1569730 usec (send/recv 1126 usec + response wait 1568604 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 1565804 usec (overhead 147 usec + queue 1553859 usec + compute input 705 usec + compute infer 11070 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 486, throughput: 323.94 infer/sec, latency 1569739 usec

# %%
#after batch 1
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963197098,"inference_count":3240,"execution_count":410,"inference_stats":{"success":{"count":3240,"ns":6945487326024},"fail":{"count":0,"ns":0},"queue":{"count":3240,"ns":6905294572267},"compute_input":{"count":3240,"ns":2288767142},"compute_infer":{"count":3240,"ns":37363372552},"compute_output":{"count":3240,"ns":74197215},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":4,"ns":678572},"compute_infer":{"count":4,"ns":3913596436},"compute_output":{"count":4,"ns":132091}},{"batch_size":2,"compute_input":{"count":2,"ns":398073},"compute_infer":{"count":2,"ns":1155454034},"compute_output":{"count":2,"ns":36906}},{"batch_size":8,"compute_input":{"count":404,"ns":285911553},"compute_infer":{"count":404,"ns":3892358506},"compute_output":{"count":404,"ns":9248914}}],"memory_usage":[]}]}

# %%
#trace 2
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 567 --request-count=1620 --async -f test2_rr567.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 567 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.947 infer/sec
#     Avg latency: 1829183 usec (standard deviation 73950 usec)
#     p50 latency: 1836503 usec
#     p90 latency: 2808079 usec
#     p95 latency: 2933598 usec
#     p99 latency: 3046894 usec
#     Avg HTTP time: 1829176 usec (send/recv 1292 usec + response wait 1827884 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 1824676 usec (overhead 144 usec + queue 1812707 usec + compute input 707 usec + compute infer 11094 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 567, throughput: 323.947 infer/sec, latency 1829183 usec

# %%
#after batch 2
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963203645,"inference_count":4860,"execution_count":615,"inference_stats":{"success":{"count":4860,"ns":9901463807097},"fail":{"count":0,"ns":0},"queue":{"count":4860,"ns":9841879935601},"compute_input":{"count":4860,"ns":3434661967},"compute_infer":{"count":4860,"ns":55337034189},"compute_output":{"count":4860,"ns":111241579},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":6,"ns":1004221},"compute_infer":{"count":6,"ns":5323841675},"compute_output":{"count":6,"ns":198699}},{"batch_size":2,"compute_input":{"count":3,"ns":595937},"compute_infer":{"count":3,"ns":1733087585},"compute_output":{"count":3,"ns":55480}},{"batch_size":8,"compute_input":{"count":606,"ns":429058234},"compute_infer":{"count":606,"ns":5818377168},"compute_output":{"count":606,"ns":13866490}}],"memory_usage":[]}]}

# %%
#trace 3
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 648 --request-count=1620 --async -f test2_rr648.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 648 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.935 infer/sec
#     Avg latency: 1999885 usec (standard deviation 67822 usec)
#     p50 latency: 2007409 usec
#     p90 latency: 2839679 usec
#     p95 latency: 2947167 usec
#     p99 latency: 3042727 usec
#     Avg HTTP time: 1999878 usec (send/recv 1039 usec + response wait 1998839 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 1996291 usec (overhead 128 usec + queue 1984363 usec + compute input 703 usec + compute infer 11074 usec + compute output 23 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 648, throughput: 323.935 infer/sec, latency 1999885 usec

# %%
#after batch 3
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963210172,"inference_count":6480,"execution_count":820,"inference_stats":{"success":{"count":6480,"ns":13135456838538},"fail":{"count":0,"ns":0},"queue":{"count":6480,"ns":13056548267298},"compute_input":{"count":6480,"ns":4574261398},"compute_infer":{"count":6480,"ns":73277348268},"compute_output":{"count":6480,"ns":148723078},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":8,"ns":1304254},"compute_infer":{"count":8,"ns":6727630040},"compute_output":{"count":8,"ns":258496}},{"batch_size":2,"compute_input":{"count":4,"ns":795888},"compute_infer":{"count":4,"ns":2310202030},"compute_output":{"count":4,"ns":73183}},{"batch_size":8,"compute_input":{"count":808,"ns":571420671},"compute_infer":{"count":808,"ns":7741164271},"compute_output":{"count":808,"ns":18539777}}],"memory_usage":[]}]}

# %%
#trace 4
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 729 --request-count=1620 --async -f test2_rr729.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 729 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.939 infer/sec
#     Avg latency: 2151973 usec (standard deviation 35679 usec)
#     p50 latency: 2161245 usec
#     p90 latency: 2878193 usec
#     p95 latency: 2970282 usec
#     p99 latency: 3054130 usec
#     Avg HTTP time: 2151966 usec (send/recv 1487 usec + response wait 2150479 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 2146937 usec (overhead 144 usec + queue 2134994 usec + compute input 705 usec + compute infer 11069 usec + compute output 23 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 729, throughput: 323.939 infer/sec, latency 2151973 usec

# %%
#after batch 4
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963216919,"inference_count":8100,"execution_count":1025,"inference_stats":{"success":{"count":8100,"ns":16613495114705},"fail":{"count":0,"ns":0},"queue":{"count":8100,"ns":16515239716145},"compute_input":{"count":8100,"ns":5717846606},"compute_infer":{"count":8100,"ns":91210609916},"compute_output":{"count":8100,"ns":186461579},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":10,"ns":1680516},"compute_infer":{"count":10,"ns":8136893756},"compute_output":{"count":10,"ns":327875}},{"batch_size":2,"compute_input":{"count":5,"ns":1006297},"compute_infer":{"count":5,"ns":2887996380},"compute_output":{"count":5,"ns":89768}},{"batch_size":8,"compute_input":{"count":1010,"ns":714269187},"compute_infer":{"count":1010,"ns":9662215425},"compute_output":{"count":1010,"ns":23244271}}],"memory_usage":[]}]}

# %%
#trace 5
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 729 --request-count=1620 --async -f test2_rr729.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 729 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.884 infer/sec
#     Avg latency: 2159274 usec (standard deviation 32512 usec)
#     p50 latency: 2167932 usec
#     p90 latency: 2885246 usec
#     p95 latency: 2978631 usec
#     p99 latency: 3061696 usec
#     Avg HTTP time: 2159267 usec (send/recv 1577 usec + response wait 2157690 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 2154059 usec (overhead 149 usec + queue 2142090 usec + compute input 706 usec + compute infer 11091 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 729, throughput: 323.884 infer/sec, latency 2159274 usec

# %%
#after batch 5
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963223672,"inference_count":9720,"execution_count":1230,"inference_stats":{"success":{"count":9720,"ns":20103071038364},"fail":{"count":0,"ns":0},"queue":{"count":9720,"ns":19985426976385},"compute_input":{"count":9720,"ns":6862008009},"compute_infer":{"count":9720,"ns":109178623269},"compute_output":{"count":9720,"ns":223054370},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":12,"ns":2081751},"compute_infer":{"count":12,"ns":9548576063},"compute_output":{"count":12,"ns":408936}},{"batch_size":2,"compute_input":{"count":6,"ns":1234557},"compute_infer":{"count":6,"ns":3466638335},"compute_output":{"count":6,"ns":107937}},{"batch_size":8,"compute_input":{"count":1212,"ns":857182143},"compute_infer":{"count":1212,"ns":11587096317},"compute_output":{"count":1212,"ns":27803695}}],"memory_usage":[]}]}

# %%
#trace 6
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 810 --request-count=1620 --async -f test2_rr810.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 810 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.905 infer/sec
#     Avg latency: 2280960 usec (standard deviation 60093 usec)
#     p50 latency: 2289770 usec
#     p90 latency: 2914836 usec
#     p95 latency: 2996272 usec
#     p99 latency: 3069754 usec
#     Avg HTTP time: 2280953 usec (send/recv 1525 usec + response wait 2279428 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 2275876 usec (overhead 150 usec + queue 2263898 usec + compute input 719 usec + compute infer 11087 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 810, throughput: 323.905 infer/sec, latency 2280960 usec

# %%
#after batch 6
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963230430,"inference_count":11340,"execution_count":1435,"inference_stats":{"success":{"count":11340,"ns":23789990692332},"fail":{"count":0,"ns":0},"queue":{"count":11340,"ns":23652943214030},"compute_input":{"count":11340,"ns":8026845538},"compute_infer":{"count":11340,"ns":127139605195},"compute_output":{"count":11340,"ns":260183770},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":14,"ns":2440744},"compute_infer":{"count":14,"ns":10967752587},"compute_output":{"count":14,"ns":496620}},{"batch_size":2,"compute_input":{"count":7,"ns":1434997},"compute_infer":{"count":7,"ns":4045193748},"compute_output":{"count":7,"ns":125243}},{"batch_size":8,"compute_input":{"count":1414,"ns":1002691850},"compute_infer":{"count":1414,"ns":13510183139},"compute_output":{"count":1414,"ns":32429583}}],"memory_usage":[]}]}

# %%
#trace 7
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 891 --request-count=1620 --async -f test2_rr891.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 891 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.944 infer/sec
#     Avg latency: 2369572 usec (standard deviation 65949 usec)
#     p50 latency: 2376974 usec
#     p90 latency: 2934089 usec
#     p95 latency: 3006505 usec
#     p99 latency: 3072762 usec
#     Avg HTTP time: 2369565 usec (send/recv 1703 usec + response wait 2367862 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 2363987 usec (overhead 144 usec + queue 2352030 usec + compute input 708 usec + compute infer 11082 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 891, throughput: 323.944 infer/sec, latency 2369572 usec

# %%
#after batch 7
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963237169,"inference_count":12960,"execution_count":1640,"inference_stats":{"success":{"count":12960,"ns":27619650608857},"fail":{"count":0,"ns":0},"queue":{"count":12960,"ns":27463233247307},"compute_input":{"count":12960,"ns":9174071888},"compute_infer":{"count":12960,"ns":145093598155},"compute_output":{"count":12960,"ns":297005148},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":16,"ns":2819026},"compute_infer":{"count":16,"ns":12383363609},"compute_output":{"count":16,"ns":566426}},{"batch_size":2,"compute_input":{"count":8,"ns":1634491},"compute_infer":{"count":8,"ns":4623566377},"compute_output":{"count":8,"ns":143593}},{"batch_size":8,"compute_input":{"count":1616,"ns":1145997985},"compute_infer":{"count":1616,"ns":15432887724},"compute_output":{"count":1616,"ns":37018942}}],"memory_usage":[]}]}

# %%
#trace 8
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 972 --request-count=1620 --async -f test2_rr972.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 972 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 323.89 infer/sec
#     Avg latency: 2427549 usec (standard deviation 18808 usec)
#     p50 latency: 2435402 usec
#     p90 latency: 2946296 usec
#     p95 latency: 3011051 usec
#     p99 latency: 3073354 usec
#     Avg HTTP time: 2427542 usec (send/recv 2242 usec + response wait 2425300 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 205
#     Successful request count: 1620
#     Avg request latency: 2421033 usec (overhead 100 usec + queue 2409217 usec + compute input 639 usec + compute infer 11058 usec + compute output 18 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 972, throughput: 323.89 infer/sec, latency 2427549 usec

# %%
#after batch 7
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963243685,"inference_count":14580,"execution_count":1845,"inference_stats":{"success":{"count":14580,"ns":31541724612969},"fail":{"count":0,"ns":0},"queue":{"count":14580,"ns":31366165277913},"compute_input":{"count":14580,"ns":10209476291},"compute_infer":{"count":14580,"ns":163008817351},"compute_output":{"count":14580,"ns":327467626},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":18,"ns":3101267},"compute_infer":{"count":18,"ns":13792891669},"compute_output":{"count":18,"ns":624594}},{"batch_size":2,"compute_input":{"count":9,"ns":1825696},"compute_infer":{"count":9,"ns":5193015533},"compute_output":{"count":9,"ns":160572}},{"batch_size":8,"compute_input":{"count":1818,"ns":1275340454},"compute_infer":{"count":1818,"ns":17353736827},"compute_output":{"count":1818,"ns":40815236}}],"memory_usage":[]}]}

# %% [markdown]
# I will run again the benchmasrks for lower utilization (ρ=0.1-0.4), to make a new graph with all of them

# %%
#trace 9
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 162 --request-count=1620 --async -f test2_rr162.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 162 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 115.701 infer/sec
#     Avg latency: 1604793 usec (standard deviation 53207 usec)
#     p50 latency: 1593410 usec
#     p90 latency: 2847703 usec
#     p95 latency: 3050269 usec
#     p99 latency: 3323769 usec
#     Avg HTTP time: 1604786 usec (send/recv 765 usec + response wait 1604021 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 209
#     Successful request count: 1620
#     Avg request latency: 1602975 usec (overhead 100 usec + queue 1558438 usec + compute input 632 usec + compute infer 43784 usec + compute output 19 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 162, throughput: 115.701 infer/sec, latency 1604793 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963260116,"inference_count":16200,"execution_count":2054,"inference_stats":{"success":{"count":16200,"ns":34138545236716},"fail":{"count":0,"ns":0},"queue":{"count":16200,"ns":33890834867936},"compute_input":{"count":16200,"ns":11234490846},"compute_infer":{"count":16200,"ns":233939594987},"compute_output":{"count":16200,"ns":359828793},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":24,"ns":3703484},"compute_infer":{"count":24,"ns":17970709856},"compute_output":{"count":24,"ns":758065}},{"batch_size":2,"compute_input":{"count":9,"ns":1825696},"compute_infer":{"count":9,"ns":5193015533},"compute_output":{"count":9,"ns":160572}},{"batch_size":3,"compute_input":{"count":1,"ns":202357},"compute_infer":{"count":1,"ns":1129632142},"compute_output":{"count":1,"ns":26400}},{"batch_size":4,"compute_input":{"count":1,"ns":322076},"compute_infer":{"count":1,"ns":440568915},"compute_output":{"count":1,"ns":18692}},{"batch_size":7,"compute_input":{"count":1,"ns":527861},"compute_infer":{"count":1,"ns":876989749},"compute_output":{"count":1,"ns":36928}},{"batch_size":8,"compute_input":{"count":2018,"ns":1402693196},"compute_infer":{"count":2018,"ns":24286594217},"compute_output":{"count":2018,"ns":44792140}}],"memory_usage":[]}]}

# %%
#trace 10
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 243 --request-count=1620 --async -f test2_rr243.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 243 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 147.248 infer/sec
#     Avg latency: 1605289 usec (standard deviation 105520 usec)
#     p50 latency: 1603341 usec
#     p90 latency: 2847691 usec
#     p95 latency: 3047891 usec
#     p99 latency: 3662286 usec
#     Avg HTTP time: 1605282 usec (send/recv 512 usec + response wait 1604770 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 207
#     Successful request count: 1620
#     Avg request latency: 1603520 usec (overhead 102 usec + queue 1565957 usec + compute input 631 usec + compute infer 36810 usec + compute output 19 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 243, throughput: 147.248 infer/sec, latency 1605289 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963272914,"inference_count":17820,"execution_count":2261,"inference_stats":{"success":{"count":17820,"ns":36736248456120},"fail":{"count":0,"ns":0},"queue":{"count":17820,"ns":36427685940246},"compute_input":{"count":17820,"ns":12257670001},"compute_infer":{"count":17820,"ns":293572679226},"compute_output":{"count":17820,"ns":391999294},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":28,"ns":4132221},"compute_infer":{"count":28,"ns":20751509930},"compute_output":{"count":28,"ns":844955}},{"batch_size":2,"compute_input":{"count":9,"ns":1825696},"compute_infer":{"count":9,"ns":5193015533},"compute_output":{"count":9,"ns":160572}},{"batch_size":3,"compute_input":{"count":1,"ns":202357},"compute_infer":{"count":1,"ns":1129632142},"compute_output":{"count":1,"ns":26400}},{"batch_size":4,"compute_input":{"count":2,"ns":647618},"compute_infer":{"count":2,"ns":881174758},"compute_output":{"count":2,"ns":38577}},{"batch_size":5,"compute_input":{"count":1,"ns":397743},"compute_infer":{"count":1,"ns":1380178039},"compute_output":{"count":1,"ns":32353}},{"batch_size":7,"compute_input":{"count":2,"ns":1015166},"compute_infer":{"count":2,"ns":1753665263},"compute_output":{"count":2,"ns":72270}},{"batch_size":8,"compute_input":{"count":2218,"ns":1529699246},"compute_infer":{"count":2218,"ns":29543124467},"compute_output":{"count":2218,"ns":48741504}}],"memory_usage":[]}]}

# %%
#trace 11
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 324 --request-count=1620 --async -f test2_rr324.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 324 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 202.47 infer/sec
#     Avg latency: 1690398 usec (standard deviation 20529 usec)
#     p50 latency: 1770150 usec
#     p90 latency: 2646071 usec
#     p95 latency: 2780875 usec
#     p99 latency: 2974641 usec
#     Avg HTTP time: 1690391 usec (send/recv 579 usec + response wait 1689812 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 206
#     Successful request count: 1620
#     Avg request latency: 1688224 usec (overhead 101 usec + queue 1663095 usec + compute input 637 usec + compute infer 24372 usec + compute output 19 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 324, throughput: 202.47 infer/sec, latency 1690398 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963282312,"inference_count":19440,"execution_count":2467,"inference_stats":{"success":{"count":19440,"ns":39471172031805},"fail":{"count":0,"ns":0},"queue":{"count":19440,"ns":39121899917327},"compute_input":{"count":19440,"ns":13290279716},"compute_infer":{"count":19440,"ns":333055570211},"compute_output":{"count":19440,"ns":423277150},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":31,"ns":4479465},"compute_infer":{"count":31,"ns":22848056045},"compute_output":{"count":31,"ns":913118}},{"batch_size":2,"compute_input":{"count":9,"ns":1825696},"compute_infer":{"count":9,"ns":5193015533},"compute_output":{"count":9,"ns":160572}},{"batch_size":3,"compute_input":{"count":1,"ns":202357},"compute_infer":{"count":1,"ns":1129632142},"compute_output":{"count":1,"ns":26400}},{"batch_size":4,"compute_input":{"count":3,"ns":912518},"compute_infer":{"count":3,"ns":1327025923},"compute_output":{"count":3,"ns":68101}},{"batch_size":5,"compute_input":{"count":2,"ns":820378},"compute_infer":{"count":2,"ns":2754172657},"compute_output":{"count":2,"ns":63346}},{"batch_size":7,"compute_input":{"count":2,"ns":1015166},"compute_infer":{"count":2,"ns":1753665263},"compute_output":{"count":2,"ns":72270}},{"batch_size":8,"compute_input":{"count":2419,"ns":1658335458},"compute_infer":{"count":2419,"ns":33134745357},"compute_output":{"count":2419,"ns":52608583}}],"memory_usage":[]}]}

# %%
#trace 12
perf_analyzer -u triton_server:8000  -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 \
    --request-distribution=poisson --request-rate-range 405 --request-count=1620 --async -f test2_rr405.csv
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Sending 1620 benchmark requests
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 405 inference requests per second
#   Client:
#     Request count: 1620
#     Throughput: 202.47 infer/sec
#     Avg latency: 1700265 usec (standard deviation 54511 usec)
#     p50 latency: 1833286 usec
#     p90 latency: 2728648 usec
#     p95 latency: 2848088 usec
#     p99 latency: 3016900 usec
#     Avg HTTP time: 1700257 usec (send/recv 645 usec + response wait 1699612 usec)
#   Server:
#     Inference count: 1620
#     Execution count: 206
#     Successful request count: 1620
#     Avg request latency: 1698014 usec (overhead 80 usec + queue 1672883 usec + compute input 630 usec + compute infer 24401 usec + compute output 19 usec)
# Inferences/Second vs. Client Average Batch Latency
# Request Rate: 405, throughput: 202.47 infer/sec, latency 1700265 usec

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":1760963291946,"inference_count":21060,"execution_count":2673,"inference_stats":{"success":{"count":21060,"ns":42221955618319},"fail":{"count":0,"ns":0},"queue":{"count":21060,"ns":41831970554692},"compute_input":{"count":21060,"ns":14311350282},"compute_infer":{"count":21060,"ns":372586121882},"compute_output":{"count":21060,"ns":455452524},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[{"batch_size":1,"compute_input":{"count":34,"ns":4847012},"compute_infer":{"count":34,"ns":24943165743},"compute_output":{"count":34,"ns":979331}},{"batch_size":2,"compute_input":{"count":9,"ns":1825696},"compute_infer":{"count":9,"ns":5193015533},"compute_output":{"count":9,"ns":160572}},{"batch_size":3,"compute_input":{"count":1,"ns":202357},"compute_infer":{"count":1,"ns":1129632142},"compute_output":{"count":1,"ns":26400}},{"batch_size":4,"compute_input":{"count":4,"ns":1258251},"compute_infer":{"count":4,"ns":1774955869},"compute_output":{"count":4,"ns":93452}},{"batch_size":5,"compute_input":{"count":3,"ns":1250061},"compute_infer":{"count":3,"ns":4129392802},"compute_output":{"count":3,"ns":94955}},{"batch_size":7,"compute_input":{"count":2,"ns":1015166},"compute_infer":{"count":2,"ns":1753665263},"compute_output":{"count":2,"ns":72270}},{"batch_size":8,"compute_input":{"count":2620,"ns":1785481917},"compute_infer":{"count":2620,"ns":36730698040},"compute_output":{"count":2620,"ns":56589797}}],"memory_usage":[]}]}

# %%
curl http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats
# Out:
# {"model_stats":[{"name":"food_classifier_onnx","version":"1","last_inference":0,"inference_count":0,"execution_count":0,"inference_stats":{"success":{"count":0,"ns":0},"fail":{"count":0,"ns":0},"queue":{"count":0,"ns":0},"compute_input":{"count":0,"ns":0},"compute_infer":{"count":0,"ns":0},"compute_output":{"count":0,"ns":0},"cache_hit":{"count":0,"ns":0},"cache_miss":{"count":0,"ns":0}},"response_stats":{},"batch_stats":[],"memory_usage":[]}]}
